# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import linear_model
import statsmodels.api as sm

# %% [markdown]
# # Data

# %%
df = pd.read_excel('dataset.xlsx') 
df = df[:-1]
df
# Out:
#                 provinsi  kode_prov    uhh    rls  pengeluaran  jumlah_vaksin  \
# 0                   ACEH       11.0  69.96  14.36    9572000.0            0.0
# 1         SUMATERA UTARA       12.0  69.23  13.27   10499000.0         1697.0
# 2         SUMATERA BARAT       13.0  69.59  14.09   10790000.0            0.0
# 3                   RIAU       14.0  71.67  13.28   10736000.0         1158.0
# 4                  JAMBI       15.0  71.22  13.04   10588000.0            0.0
# 5       SUMATERA SELATAN       16.0  69.98  12.54   10662000.0         1855.0
# 6               BENGKULU       17.0  69.42  13.67   10487000.0            0.0
# 7                LAMPUNG       18.0  70.73  12.73   10038000.0            8.0
# 8   KEP. BANGKA BELITUNG       19.0  70.73  12.17   12819000.0            3.0
# 9         KEPULAUAN RIAU       20.0  70.12  12.98   14122000.0          627.0
# 10           DKI JAKARTA       31.0  73.01  13.07   18520000.0      1234538.0
# 11            JAWA BARAT       32.0  73.23  12.61   10934000.0       105133.0
# 12           JAWA TENGAH       33.0  74.47  12.77   11034000.0         8546.0
# 13        D I YOGYAKARTA       34.0  75.04  15.64   14111000.0         2503.0
# 14            JAWA TIMUR       35.0  71.38  13.36   11707000.0        84378.0
# 15                BANTEN       36.0  70.02  13.02   12033000.0       129728.0
# 16                  BALI       51.0  72.24  13.40   13820000.0        26200.0
# 17   NUSA TENGGARA BARAT       52.0  66.69  13.90   10377000.0           24.0
# 18   NUSA TENGGARA TIMUR       53.0  67.15  13.20    7554000.0           15.0
# 19      KALIMANTAN BARAT       61.0  70.76  12.65    8974000.0           77.0
# 20     KALIMANTAN TENGAH       62.0  69.79  12.74   11182000.0           39.0
# 21    KALIMANTAN SELATAN       63.0  68.83  12.81   12143000.0            0.0
# 22      KALIMANTAN TIMUR       64.0  74.61  13.81   12116000.0          593.0
# 23      KALIMANTAN UTARA       65.0  72.65  12.94    9075000.0            0.0
# 24        SULAWESI UTARA       71.0  71.76  12.94   10882000.0            0.0
# 25       SULAWESI TENGAH       72.0  68.83  13.23    9378000.0            0.0
# 26      SULAWESI SELATAN       73.0  70.66  13.52   11184000.0           37.0
# 27     SULAWESI TENGGARA       74.0  71.27  13.68    9381000.0           17.0
# 28             GORONTALO       75.0  68.19  13.11   10157000.0            0.0
# 29        SULAWESI BARAT       76.0  65.25  12.86    9153000.0            0.0
# 30                MALUKU       81.0  66.09  13.97    8770000.0            0.0
# 31          MALUKU UTARA       82.0  68.45  13.68    8140000.0            0.0
# 32           PAPUA BARAT       91.0  66.14  13.13    7929000.0            1.0
# 33                 PAPUA       94.0  65.93  11.11    6955000.0            0.0
#
#     real_kesehatan  real_pendidikan  jumlah_kunjungan         pdrb   tpt  \
# 0     4.620580e+11     4.294573e+13                 0   34680460.0  5.97
# 1     1.202177e+12     1.944434e+13              1136   57569790.0  5.47
# 2     1.279751e+12     6.874831e+12                 0   45293750.0  6.17
# 3     2.662071e+11     2.283546e+13               445  129852590.0  4.40
# 4     3.145637e+11     3.881317e+12                 2   65193220.0  4.70
# 5     1.512383e+12     7.922621e+12              1855   57487440.0  4.74
# 6     2.507018e+11     3.688498e+12                 0   39143430.0  3.39
# 7     4.652002e+11     1.837241e+14                 6   40950420.0  4.31
# 8     2.234118e+11     1.179135e+12                 2   58338820.0  4.18
# 9     5.123387e+11     3.754633e+12                 2  130125230.0  8.02
# 10    4.249230e+14     1.789077e+14            950032  274709590.0  8.00
# 11    3.387430e+12     6.083100e+13             75950   45299580.0  8.35
# 12    4.021657e+12     7.918727e+13              7751   38669110.0  5.75
# 13    1.498018e+12     1.282083e+13              2465   40229830.0  3.73
# 14    2.086331e+12     4.107277e+13             82954   60043330.0  4.81
# 15    4.626987e+11     2.946799e+13            114860   55210650.0  8.53
# 16    1.265989e+12     1.560218e+13             26028   50381210.0  4.84
# 17    2.639014e+11     6.453881e+12                 9   26002480.0  3.92
# 18    3.803239e+11     9.204214e+12                 0   20581130.0  3.30
# 19    3.125553e+11     9.028493e+12                76   42282900.0  4.86
# 20    6.328339e+11     4.335401e+12                39   62912850.0  4.20
# 21    7.109031e+11     1.495521e+13                 0   46712680.0  4.20
# 22    3.565913e+11     1.053252e+13                 7  182540820.0  6.77
# 23    6.432457e+10     2.111406e+12                 0  155080620.0  4.62
# 24    9.316965e+11     5.350309e+12                 0   54043180.0  6.51
# 25    3.131722e+11     5.504411e+12                 0   81733040.0  3.67
# 26    1.668189e+12     1.103979e+13                32   59656240.0  5.75
# 27    2.555202e+11     8.315941e+12                17   52293970.0  3.86
# 28    1.914190e+11     2.417572e+12                 0   37170450.0  3.25
# 29    1.396688e+11     2.978106e+12                 0   35036020.0  3.11
# 30    3.992229e+11     4.975812e+12                 0   26072980.0  6.44
# 31    1.785783e+11     4.233113e+12                 0   40302320.0  4.98
# 32    2.227033e+11     4.328281e+12                 1   73539000.0  5.78
# 33    4.730902e+11     2.352001e+12                 0   54034260.0  3.60
#
#       ipm
# 0   71.99
# 1   71.77
# 2   72.38
# 3   72.71
# 4   71.29
# 5   70.01
# 6   71.40
# 7   69.69
# 8   71.47
# 9   75.59
# 10  80.77
# 11  72.09
# 12  71.87
# 13  79.97
# 14  71.71
# 15  72.45
# 16  75.50
# 17  68.25
# 18  65.19
# 19  67.66
# 20  71.05
# 21  70.91
# 22  76.24
# 23  70.63
# 24  72.93
# 25  69.55
# 26  71.93
# 27  71.45
# 28  68.68
# 29  66.11
# 30  69.49
# 31  68.49
# 32  65.09
# 33  60.44

# %% [markdown]
# # Data Y1

# %%
X = df[['jumlah_vaksin','real_kesehatan']]
Y = df['uhh'].to_frame()

# %%
# from scipy.stats import zscore
# X = X.apply(zscore)
# Y = Y.apply(zscore)

# %%
for column in X.columns:
    X[column] = (X[column] - X[column].min()) / (X[column].max() - X[column].min())
# Out:
# C:\Users\221911079\AppData\Local\Temp\ipykernel_14940\3233899070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = (X[column] - X[column].min()) / (X[column].max() - X[column].min())

# %%
# for column in Y.columns:
#     Y[column] = (Y[column] - Y[column].min()) / (Y[column].max() - Y[column].min())

# %%
X.head()
# Out:
#    jumlah_vaksin  real_kesehatan
# 0       0.000000        0.000936
# 1       0.001375        0.002678
# 2       0.000000        0.002861
# 3       0.000938        0.000475
# 4       0.000000        0.000589

# %%
Y.head()
# Out:
#      uhh
# 0  69.96
# 1  69.23
# 2  69.59
# 3  71.67
# 4  71.22

# %% [markdown]
# # Model Y1

# %%
regr1 = linear_model.LinearRegression()
regr1.fit(X, Y)
# Out:
# LinearRegression()

# %%
print(regr1.coef_)
# Out:
# [[ 18.25725283 -15.09690009]]

# %%
Y1 = regr1.predict(X)

# %%
X2 = sm.add_constant(X)
est = sm.OLS(Y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    uhh   R-squared:                       0.074
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     1.243
# Date:                Mon, 24 Oct 2022   Prob (F-statistic):              0.302
# Time:                        22:26:41   Log-Likelihood:                -77.751
# No. Observations:                  34   AIC:                             161.5
# Df Residuals:                      31   BIC:                             166.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             69.9247      0.453    154.276      0.000      69.000      70.849
# jumlah_vaksin     18.2573     17.826      1.024      0.314     -18.098      54.613
# real_kesehatan   -15.0969     17.889     -0.844      0.405     -51.582      21.388
# ==============================================================================
# Omnibus:                        0.085   Durbin-Watson:                   0.957
# Prob(Omnibus):                  0.959   Jarque-Bera (JB):                0.100
# Skew:                           0.085   Prob(JB):                        0.951
# Kurtosis:                       2.795   Cond. No.                         59.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df.head()
# Out:
#          provinsi  kode_prov    uhh    rls  pengeluaran  jumlah_vaksin  \
# 0            ACEH       11.0  69.96  14.36    9572000.0            0.0
# 1  SUMATERA UTARA       12.0  69.23  13.27   10499000.0         1697.0
# 2  SUMATERA BARAT       13.0  69.59  14.09   10790000.0            0.0
# 3            RIAU       14.0  71.67  13.28   10736000.0         1158.0
# 4           JAMBI       15.0  71.22  13.04   10588000.0            0.0
#
#    real_kesehatan  real_pendidikan  jumlah_kunjungan         pdrb   tpt    ipm
# 0    4.620580e+11     4.294573e+13                 0   34680460.0  5.97  71.99
# 1    1.202177e+12     1.944434e+13              1136   57569790.0  5.47  71.77
# 2    1.279751e+12     6.874831e+12                 0   45293750.0  6.17  72.38
# 3    2.662071e+11     2.283546e+13               445  129852590.0  4.40  72.71
# 4    3.145637e+11     3.881317e+12                 2   65193220.0  4.70  71.29

# %% [markdown]
# # Data Y2

# %%
X = df[['real_pendidikan']]
Y = df['rls'].to_frame()

# %%
type(Y)
# Out:
# pandas.core.frame.DataFrame

# %%
# from scipy.stats import zscore
# X = X.apply(zscore)
# Y = Y.apply(zscore)

# %%
for column in X.columns:
    X[column] = (X[column] - X[column].min()) / (X[column].max() - X[column].min())
# Out:
# C:\Users\221911079\AppData\Local\Temp\ipykernel_14940\3233899070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = (X[column] - X[column].min()) / (X[column].max() - X[column].min())

# %%
# for column in Y.columns:
#     Y[column] = (Y[column] - Y[column].min()) / (Y[column].max() - Y[column].min())

# %%
X.head()
# Out:
#    real_pendidikan
# 0         0.228802
# 1         0.100059
# 2         0.031202
# 3         0.118636
# 4         0.014803

# %%
Y.head()
# Out:
#      rls
# 0  14.36
# 1  13.27
# 2  14.09
# 3  13.28
# 4  13.04

# %% [markdown]
# # Model Y2

# %%
regr2 = linear_model.LinearRegression()
regr2.fit(X, Y)
# Out:
# LinearRegression()

# %%
print(regr2.coef_)
# Out:
# [[-0.28925976]]

# %%
Y2 = regr2.predict(X)

# %%
X2 = sm.add_constant(X)
est = sm.OLS(Y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    rls   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.022
# Method:                 Least Squares   F-statistic:                    0.2808
# Date:                Mon, 24 Oct 2022   Prob (F-statistic):              0.600
# Time:                        22:26:42   Log-Likelihood:                -37.353
# No. Observations:                  34   AIC:                             78.71
# Df Residuals:                      32   BIC:                             81.76
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              13.2506      0.146     91.006      0.000      12.954      13.547
# real_pendidikan    -0.2893      0.546     -0.530      0.600      -1.401       0.823
# ==============================================================================
# Omnibus:                        9.388   Durbin-Watson:                   1.592
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               16.471
# Skew:                           0.397   Prob(JB):                     0.000265
# Kurtosis:                       6.316   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Data Y3

# %%
X = df[['jumlah_kunjungan','pdrb','tpt']]
Y = df['pengeluaran'].to_frame()

# %%
type(Y)
# Out:
# pandas.core.frame.DataFrame

# %%
# from scipy.stats import zscore
# X = X.apply(zscore)
# Y = Y.apply(zscore)

# %%
for column in X.columns:
    X[column] = (X[column] - X[column].min()) / (X[column].max() - X[column].min())
# Out:
# C:\Users\221911079\AppData\Local\Temp\ipykernel_14940\3233899070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = (X[column] - X[column].min()) / (X[column].max() - X[column].min())

# %%
# for column in Y.columns:
#     Y[column] = (Y[column] - Y[column].min()) / (Y[column].max() - Y[column].min())

# %%
X.head()
# Out:
#    jumlah_kunjungan      pdrb       tpt
# 0          0.000000  0.055481  0.527675
# 1          0.001196  0.145551  0.435424
# 2          0.000000  0.097245  0.564576
# 3          0.000468  0.429985  0.238007
# 4          0.000002  0.175549  0.293358

# %%
Y.head()
# Out:
#    pengeluaran
# 0    9572000.0
# 1   10499000.0
# 2   10790000.0
# 3   10736000.0
# 4   10588000.0

# %% [markdown]
# # Model Y3

# %%
regr3 = linear_model.LinearRegression()
regr3.fit(X, Y)
# Out:
# LinearRegression()

# %%
print(regr3.coef_)
# Out:
# [[5719781.94251719 2023879.74569898 1381009.32497958]]

# %%
Y3 = regr3.predict(X)

# %%
X2 = sm.add_constant(X)
est = sm.OLS(Y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            pengeluaran   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.414
# Method:                 Least Squares   F-statistic:                     8.766
# Date:                Mon, 24 Oct 2022   Prob (F-statistic):           0.000251
# Time:                        22:26:42   Log-Likelihood:                -533.78
# No. Observations:                  34   AIC:                             1076.
# Df Residuals:                      30   BIC:                             1082.
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             9.654e+06   5.48e+05     17.604      0.000    8.53e+06    1.08e+07
# jumlah_kunjungan   5.72e+06   2.42e+06      2.360      0.025     7.7e+05    1.07e+07
# pdrb              2.024e+06   2.06e+06      0.985      0.333   -2.17e+06    6.22e+06
# tpt               1.381e+06   1.17e+06      1.176      0.249   -1.02e+06    3.78e+06
# ==============================================================================
# Omnibus:                        2.160   Durbin-Watson:                   1.110
# Prob(Omnibus):                  0.340   Jarque-Bera (JB):                1.167
# Skew:                           0.415   Prob(JB):                        0.558
# Kurtosis:                       3.368   Cond. No.                         10.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
